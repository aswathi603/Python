# %% [markdown]
# # 📘 Income Classification - Adult Dataset Analysis

# %%
from IPython.display import Image, display, Markdown
import pandas as pd

# %% [markdown]
# ![Income Classification - Adult Dataset Analysis](Image1.png )

# %% [markdown]
# 📄 About the Dataset
#
# This dataset is extracted from the **UCI Machine Learning Repository** and is also known as the **"Adult" or "Census Income" dataset**.
#
# It contains information about individuals from the 1994 Census database. The goal is to predict whether a person earns more than `$50K` a year based on attributes like age, education, workclass, etc.
#
# 📌 **Source**: [UCI Adult Dataset](https://archive.ics.uci.edu/ml/datasets/adult)

# %%
# 📥 Load and Preview Data
df = pd.read_csv("adult_data.csv", header=None, skipinitialspace=True)

# %%
# Adding column names as per the UCI repository
df.columns = [
    "age", "workclass", "fnlwgt", "education", "education-num", "marital-status",
    "occupation", "relationship", "race", "sex", "capital-gain", "capital-loss",
    "hours-per-week", "native-country", "income"
]

# %%
# Show the first 5 rows
df.head()
# Out:
#    age         workclass  fnlwgt  education  education-num  \
# 0   39         State-gov   77516  Bachelors             13
# 1   50  Self-emp-not-inc   83311  Bachelors             13
# 2   38           Private  215646    HS-grad              9
# 3   53           Private  234721       11th              7
# 4   28           Private  338409  Bachelors             13
#
#        marital-status         occupation   relationship   race     sex  \
# 0       Never-married       Adm-clerical  Not-in-family  White    Male
# 1  Married-civ-spouse    Exec-managerial        Husband  White    Male
# 2            Divorced  Handlers-cleaners  Not-in-family  White    Male
# 3  Married-civ-spouse  Handlers-cleaners        Husband  Black    Male
# 4  Married-civ-spouse     Prof-specialty           Wife  Black  Female
#
#    capital-gain  capital-loss  hours-per-week native-country income
# 0          2174             0              40  United-States  <=50K
# ...

# %%
## Dataset info 
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32561 entries, 0 to 32560
# Data columns (total 15 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   age             32561 non-null  int64
#  1   workclass       32561 non-null  object
#  2   fnlwgt          32561 non-null  int64
#  3   education       32561 non-null  object
#  4   education-num   32561 non-null  int64
#  5   marital-status  32561 non-null  object
#  6   occupation      32561 non-null  object
#  7   relationship    32561 non-null  object
#  8   race            32561 non-null  object
#  9   sex             32561 non-null  object
#  10  capital-gain    32561 non-null  int64
#  11  capital-loss    32561 non-null  int64
#  12  hours-per-week  32561 non-null  int64
#  13  native-country  32561 non-null  object
#  14  income          32561 non-null  object
# dtypes: int64(6), object(9)
# memory usage: 3.7+ MB

# %%
#Summary of Unique Values per Column
df.nunique()
# Out:
# age                  73
# workclass             9
# fnlwgt            21648
# education            16
# education-num        16
# marital-status        7
# occupation           15
# relationship          6
# race                  5
# sex                   2
# capital-gain        119
# capital-loss         92
# hours-per-week       94
# native-country       42
# income                2
# dtype: int64

# %%
#checking the missing value 
df.isin(['?']).sum()
# Out:
# age                  0
# workclass         1836
# fnlwgt               0
# education            0
# education-num        0
# marital-status       0
# occupation        1843
# relationship         0
# race                 0
# sex                  0
# capital-gain         0
# capital-loss         0
# hours-per-week       0
# native-country     583
# income               0
# dtype: int64

# %% [markdown]
# ### Interesting Textual Insights

# %%
#Income Distribution 
income_count = df['income'].value_counts()
display(income_count)
# Out:
# income
# <=50K    24720
# >50K      7841
# Name: count, dtype: int64

# %% [markdown]
# Analyze the impact of marital status on income levels.
#
# Investigate the relationship between age and income.
#
# Explore the effect of education on job type and income.
#
# Examine the correlation between hours worked per week and income.
#
# Assess the influence of gender on income disparities.
#
# Analyze the distribution of income across different occupations.
#
# Investigate the relationship between race and income levels.
#
# Explore the geographical trends in income based on state or region.
#
# Assess the impact of work experience on income.
#
# Analyze the effect of industry type on income levels.
#
# Analyze the impact of marital status on income levels.
#
# Investigate the relationship between age and income.
#
# Explore the effect of education on job type and income.
#
# Examine the correlation between hours worked per week and income.
#
# Assess the influence of gender on income disparities.
#
# Analyze the distribution of income across different occupations.
#
# Investigate the relationship between race and income levels.
#
# Explore the geographical trends in income based on state or region.
#
# Assess the impact of work experience on income.
#
# Analyze the effect of industry type on income levels.
